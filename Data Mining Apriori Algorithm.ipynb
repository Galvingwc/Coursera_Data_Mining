# %%
#import libraries
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
#import text file data
file = open(r"C:\Users\Galvin\Desktop\categories.txt", "r")
data = [line.strip('\n').split(';') for line in file]
data
# Out:
# [['Breakfast & Brunch', 'American (Traditional)', 'Restaurants'],
#  ['Sandwiches', 'Restaurants'],
#  ['Local Services', 'IT Services & Computer Repair'],
#  ['Restaurants', 'Italian'],
#  ['Food', 'Coffee & Tea'],
#  ['Fast Food', 'Restaurants'],
#  ['Mortgage Brokers', 'Home Services', 'Real Estate'],
#  ['Brasseries', 'Restaurants'],
#  ['Bars',
#   'Sports Bars',
#   'Nightlife',
#   'American (New)',
#   'Chicken Wings',
#   'Restaurants'],
#  ['Automotive',
#   'Windshield Installation & Repair',
#   'Auto Detailing',
#   'Wheel & Rim Repair'],
#  ['Automotive', 'Auto Parts & Supplies'],
#  ['Food', 'Grocery', 'CSA', 'Farmers Market'],
#  ['Specialty Schools', 'CPR Classes', 'First Aid Classes', 'Education'],
#  ['Event Planning & Services', 'Venues & Event Spaces'],
#  ['Shopping', 'Home Decor', 'Home & Garden', 'Furniture Stores'],
#  ['Books, Mags, Music & Video', 'Shopping', 'Bookstores'],
#  ['Auto Repair', 'Automotive'],
#  ['Local Services', 'Dry Cleaning & Laundry'],
# ...

# %%
#transform data into transaction encoded dataframe
te = TransactionEncoder()
te_array = te.fit_transform(data)
df = pd.DataFrame(te_array, columns=te.columns_)
df
# Out:
#        ATV Rentals/Tours  Accessories  Accountants  Active Life  Acupuncture  \
# 0                  False        False        False        False        False
# 1                  False        False        False        False        False
# 2                  False        False        False        False        False
# 3                  False        False        False        False        False
# 4                  False        False        False        False        False
# ...                  ...          ...          ...          ...          ...
# 77180              False        False        False        False        False
# 77181              False        False        False        False        False
# 77182              False        False        False        False        False
# 77183              False        False        False        False        False
# 77184              False        False        False        False        False
#
# ...

# %%
#mine data with at least 1% support
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.040202                                      (Active Life)
# 1    0.020639                                   (American (New))
# 2    0.031301                           (American (Traditional))
# 3    0.029423                             (Arts & Entertainment)
# 4    0.022232                                      (Auto Repair)
# ..        ...                                                ...
# 96   0.010598                     (Bars, Nightlife, Sports Bars)
# 97   0.010028                  (Restaurants, Fast Food, Burgers)
# 98   0.010663    (Health & Medical, Dentists, General Dentistry)
# 99   0.018540  (Hotels & Travel, Hotels, Event Planning & Ser...
# 100  0.014744              (Shopping, Women's Clothing, Fashion)
#
# [101 rows x 2 columns]

# %%
#insert length column into dataframe
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets['support'] = 77185*frequent_itemsets['support']
frequent_itemsets['support'] = frequent_itemsets['support'].astype(int)
frequent_itemsets
# Out:
#      support                                           itemsets  length
# 0       3103                                      (Active Life)       1
# 1       1593                                   (American (New))       1
# 2       2416                           (American (Traditional))       1
# 3       2271                             (Arts & Entertainment)       1
# 4       1716                                      (Auto Repair)       1
# ..       ...                                                ...     ...
# 96       818                     (Bars, Nightlife, Sports Bars)       3
# 97       774                  (Restaurants, Fast Food, Burgers)       3
# 98       823    (Health & Medical, Dentists, General Dentistry)       3
# 99      1430  (Hotels & Travel, Hotels, Event Planning & Ser...       3
# 100     1138              (Shopping, Women's Clothing, Fashion)       3
#
# [101 rows x 3 columns]

# %%
#length 1 frequent item dataframe
frequent_itemsets1 = frequent_itemsets[frequent_itemsets['length']==1]
frequent_itemsets1
# Out:
#     support                     itemsets  length
# 0      3103                (Active Life)       1
# 1      1593             (American (New))       1
# 2      2416     (American (Traditional))       1
# 3      2271       (Arts & Entertainment)       1
# 4      1716                (Auto Repair)       1
# 5      4208                 (Automotive)       1
# 6      1115                   (Bakeries)       1
# 7      4328                       (Bars)       1
# 8      6583              (Beauty & Spas)       1
# 9      1369         (Breakfast & Brunch)       1
# 10     1774                    (Burgers)       1
# 11     1002                      (Cafes)       1
# 12     1629                    (Chinese)       1
# 13     2199               (Coffee & Tea)       1
# 14     1195                   (Dentists)       1
# 15     1694                    (Doctors)       1
# 16     2975  (Event Planning & Services)       1
# 17     3078                    (Fashion)       1
# ...

# %%
#export length 1 dataframe as text file
frequent_itemsets1.drop(columns=['length']).to_csv(r'C:\Users\Galvin\Desktop\patterns.txt', header=None, index=None, sep=':', mode='a')

# %%
#export all frequent dataframe as text file
frequent_itemsets.drop(columns=['length']).to_csv(r'C:\Users\Galvin\Desktop\patterns1.txt', header=None, index=None, sep=':', mode='a')
